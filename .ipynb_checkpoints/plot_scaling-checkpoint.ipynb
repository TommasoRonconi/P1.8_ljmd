# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Define a linear function to compute the ideal speed-up:

# %%
def lin_func (_nn) :
    plot(_nn, _nn, "--k")

# %% [markdown]
# Function to process input file

# %%
def process_input (_nn, _tt,step=10) :
    nn = numpy.array([])
    tt = numpy.array([])
    te = numpy.array([])
    jj = 10
    for ii in range(10, len(_nn), step) :
        nn = numpy.append(nn, _nn[ii])
        tt = numpy.append(tt, numpy.mean(_tt[ii:ii+step]))
        te = numpy.append(te, numpy.std(_tt[ii:ii+step]))
    return nn, tt, te

# %% [markdown]
# Input files:

# %%
npart = [108, 2916]
filein_108 = "input/time_argon_108.txt"
filein_2916 = ""

# %% [markdown]
# Plot **strong scaling**:

# %%
figure(figsize(12,8))
xlabel("nodes", fontsize=18)
ylabel("speed-up $[T(1)/T(N_\\mathrm{nodes})]$", fontsize=18)
title("Computation", fontsize=20)

for size in npart :
    file_in = "times_omp_"+str(size)+".dat"
    _nn, _t_comm, _t_comp = numpy.genfromtxt(file_in, usecols=(0,2,3), unpack=True)
    nn, tt, te = process_input(_nn, _t_comp)
    plot(nn, tt[0]/tt)
    fill_between(nn, tt[0]/(tt-5*te), tt[0]/(tt+5*te), alpha=0.4, label="particles = "+str(size))

legend(loc="upper left", fontsize=18)
lin_func(nn)
savefig("output/strong_scaling_comp.png", bbox_inches=\'tight')

# %%
figure(figsize(12,8))
xlabel("nodes", fontsize=18)
ylabel("speed-up $[T(1)/T(N_\\mathrm{nodes})]$", fontsize=18)
title("Communication + Computation", fontsize=20)

for size in npart :
    file_in = "input/time_argon_"+str(size)+".txt"
    _nn, _t_comm, _t_comp = numpy.genfromtxt(file_in, usecols=(0,2,3), unpack=True)
    nn, tt, te = process_input(_nn, _t_comp+_t_comm)
    plot(nn, tt[0]/tt)
    fill_between(nn, tt[0]/(tt-5*te), tt[0]/(tt+5*te), alpha=0.4, label="particles = "+str(size))

legend(loc="upper left", fontsize=18)
lin_func(nn)
savefig("output/strong_scaling_comm+comp.png", bbox_inches='tight')
